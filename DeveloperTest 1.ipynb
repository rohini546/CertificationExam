# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, Aer, IBMQ, execute
from qiskit.tools.jupyter import *
from qiskit.visualization import *
from ibm_quantum_widgets import *
from qiskit.providers.aer import QasmSimulator

# Loading your IBM Quantum account(s)
provider = IBMQ.load_account()
backend = Aer.get_backend('statevector_simulator')
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
import numpy as np
from math import pi

# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, transpile
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer

backend = BasicAer.get_backend('unitary_simulator')

# %%
qc=QuantumCircuit(1)
#qc.rx(3*math.pi/4,0)
qc.rx(3*pi/4,0)

# %%
qc.draw()

# %%
backend = Aer.get_backend('statevector_simulator')

out1 = execute(qc,backend).result().get_statevector()
plot_bloch_multivector(out1)
# Out:
# /opt/conda/lib/python3.8/site-packages/qiskit/visualization/bloch.py:69: MatplotlibDeprecationWarning:
# The M attribute was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use self.axes.M instead.
#   x_s, y_s, _ = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)

# %%
job = backend.run(transpile(qc, backend))
job.result().get_unitary(qc, decimals=3)
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_77/1544215966.py", line 2, in <module>
#     job.result().get_unitary(qc, decimals=3)
#   File "/opt/conda/lib/python3.8/site-packages/qiskit/result/result.py", line 349, in get_unitary
#     raise QiskitError(f'No unitary for experiment "{repr(experiment)}"') from ex
# QiskitError: 'No unitary for experiment "<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7f8d38c8dd60>"'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=QiskitError: No unitary for experiment "<qiskit.circuit.quantumcircuit.QuantumCircuit object at 0x7f8d38c8dd60>"" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
#Q4
qc=QuantumCircuit(2,2)
qc.h(0)
qc.h(1)

# %%
qc.qasm_simulator()
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_77/1640512500.py", line 1, in <module>
#     qc.qasm_simulator()
# AttributeError: 'QuantumCircuit' object has no attribute 'qasm_simulator'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: 'QuantumCircuit' object has no attribute 'qasm_simulator'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
qc.qasm_str()
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_77/1951622342.py", line 1, in <module>
#     qc.qasm_str()
# AttributeError: 'QuantumCircuit' object has no attribute 'qasm_str'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: 'QuantumCircuit' object has no attribute 'qasm_str'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
qc.qasm()
# Out:
# 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[2];\ncreg c[2];\nh q[0];\nh q[1];\n'

# %%
qc.from_qasm()
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_77/128473933.py", line 1, in <module>
#     qc.from_qasm()
# AttributeError: 'QuantumCircuit' object has no attribute 'from_qasm'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: 'QuantumCircuit' object has no attribute 'from_qasm'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
import qiskit
qiskit.__qiskit_version__
# Out:
# /opt/conda/lib/python3.8/site-packages/qiskit/aqua/__init__.py:86: DeprecationWarning: The package qiskit.aqua is deprecated. It was moved/refactored to qiskit-terra For more information see <https://github.com/Qiskit/qiskit-aqua/blob/main/README.md#migration-guide>
#   warn_package('aqua', 'qiskit-terra')
# {'qiskit-terra': '0.18.3', 'qiskit-aer': '0.9.1', 'qiskit-ignis': '0.6.0', 'qiskit-ibmq-provider': '0.17.0', 'qiskit-aqua': '0.9.5', 'qiskit': '0.31.0', 'qiskit-nature': '0.2.2', 'qiskit-finance': '0.2.1', 'qiskit-optimization': '0.2.3', 'qiskit-machine-learning': '0.2.1'}

# %%
#Q8
q = QuantumRegister(2,"qreg") 
c = ClassicalRegister(2,"creg") 
qc = QuantumCircuit(q,c) 
qc.x(q[0]) 
qc.measure(q,c) 
job = execute(qc,Aer.get_backend('qasm_simulator'),shots=1024) 
counts = job.result().get_counts(qc) 
print(counts)
# Out:
# {'01': 1024}

# %%
#Q10
q = QuantumRegister(3)
c = ClassicalRegister(3)
qc = QuantumCircuit(q,c)
qc.h(q[0:3])
qc.x(q[0:3])
qc.z(q[0:3])
qc.draw(output='mpl')

# %%
qc.size()
# Out:
# 9

# %%
qc.path()
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_77/1895992466.py", line 1, in <module>
#     qc.path()
# AttributeError: 'QuantumCircuit' object has no attribute 'path'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: 'QuantumCircuit' object has no attribute 'path'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
qc.depth()
# Out:
# 3

# %%
qc.depth_display()
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_77/680711294.py", line 1, in <module>
#     qc.depth_display()
# AttributeError: 'QuantumCircuit' object has no attribute 'depth_display'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: 'QuantumCircuit' object has no attribute 'depth_display'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
#Q12
from qiskit import QuantumRegister, ClassicalRegister,QuantumCircuit,execute,Aer
qc=QuantumCircuit(2,2)

# %%
qc.z(1)
qc.x(1)

# %%
#Q14
qc=QuantumCircuit(1,1)
qc.x(0)

# %%
qc.measure(0,0)

# %%
q = QuantumRegister(2,'q')
qc1 = QuantumCircuit(q)
qc1.h(q[0:2])
qc1.s(q[0:2])
qc1.draw(output='mpl')

# %%
q = QuantumRegister(2,'q')
qc2 = QuantumCircuit(q)
qc2.h(q[0:2])
qc2.x(q[0:2])
qc1.draw(output='mpl')

# %%
(qc1+qc2).draw(output='mpl')
# Out:
# /tmp/ipykernel_60/226026286.py:1: DeprecationWarning: The QuantumCircuit.__add__() method is being deprecated.Use the compose() method which is more flexible w.r.t circuit register compatibility.
#   (qc1+qc2).draw(output='mpl')

# %%
qc1.add(qc2)
qc1.draw()
# Out:
# Traceback (most recent call last):
#   Input In [8] in <cell line: 1>
#     qc1.add(qc2)
# AttributeError: 'QuantumCircuit' object has no attribute 'add'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: 'QuantumCircuit' object has no attribute 'add'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
#Q22
q = QuantumRegister(2,'q')
c = ClassicalRegister(2,'c')
qc = QuantumCircuit(q,c)
qc.h(0)
qc.h(1)
qc.measure([0,1],[0,1])
qc.draw(output='mpl')
backend = BasicAer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=100)
counts = job.result().get_counts()

# %%
counts
# Out:
# {'01': 33, '11': 15, '00': 32, '10': 20}

# %%
#Q23
q = QuantumRegister(3,'q')
c = ClassicalRegister(3,'c')
qc = QuantumCircuit(q,c)
qc.h(0)
qc.cnot(0,1)
qc.cnot(0,2)
qc.measure([0,2],[0,2])
qc.draw(output='mpl')
backend = BasicAer.get_backend('qasm_simulator')
job = execute(qc, backend, shots=100)
counts = job.result().get_counts()

# %%
counts
# Out:
# {'000': 47, '101': 53}

# %%
#Q29
qc = QuantumCircuit(2,2)
qc.h(0)
qc.t(0)
qc.t(0)
qc.h(0)

# %%
sim=BasicAer.get_backend('qasm_simulator')
result=execute(qc,sim,shots=1024).results()
counts=result.get_counts()
print(counts)
# Out:
# No measurements in circuit "circuit-3", classical register will remain all zeros.
# Traceback (most recent call last):
#   File "/tmp/ipykernel_170/3745924921.py", line 2, in <module>
#     result=execute(qc,sim,shots=1024).results()
# AttributeError: 'BasicAerJob' object has no attribute 'results'
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: 'BasicAerJob' object has no attribute 'results'" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
sim=BasicAer.get_backend('statevector_simulator')
result=execute(qc,sim).result()
counts=result.get_statevector(qc)
print(counts)
# Out:
# [0.5+0.5j 0.5-0.5j 0. +0.j  0. +0.j ]

# %%
sim=BasicAer.get_backend('qasm_simulator')
result=execute(qc,sim).result()
counts=result.get_counts()
print(counts)
# Out:
# No measurements in circuit "circuit-125", classical register will remain all zeros.
# {'00': 1024}

# %%
sim=BasicAer.get_backend('unitary_simulator')
result=execute(qc,sim,shots=1024).result()
counts=result.get_unitary()
print(counts)
# Out:
# [[0.5+0.5j 0.5-0.5j 0. +0.j  0. +0.j ]
#  [0.5-0.5j 0.5+0.5j 0. +0.j  0. +0.j ]
#  [0. +0.j  0. +0.j  0.5+0.5j 0.5-0.5j]
#  [0. +0.j  0. +0.j  0.5-0.5j 0.5+0.5j]]

# %%
sim=BasicAer.get_backend('qasm_simulator')
result=execute(qc,sim,shots=1024).result()
counts=result.get_counts()
print(counts)
# Out:
# No measurements in circuit "circuit-172", classical register will remain all zeros.
# {'00': 1024}

# %%
#Q30
qc = QuantumCircuit(3)
qc.h(0)
qc.cx([0,1],[1,2])
backend = BasicAer.get_backend('statevector_simulator')
job = execute(qc, backend, shots=1024) 
result = job.result()

# %%
print(result.get_statevector(qc))
# Out:
# [0.70710678+0.j 0.        +0.j 0.        +0.j 0.        +0.j
#  0.        +0.j 0.        +0.j 0.        +0.j 0.70710678+0.j]

# %%
sv=statevector.from_label('000')
sv_ev=sv.evolve(qc)
sv_ev.draw()
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_170/633946655.py", line 1, in <module>
#     sv=statevector.from_label('000')
# NameError: name 'statevector' is not defined
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=NameError: name 'statevector' is not defined" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
print(result.get_state(qc))
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_170/538286121.py", line 1, in <module>
#     print(result.get_state(qc))
#   File "/opt/conda/lib/python3.8/site-packages/qiskit/result/result.py", line 128, in __getattr__
#     raise AttributeError(f"Attribute {name} is not defined") from ex
# AttributeError: Attribute get_state is not defined
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: Attribute get_state is not defined" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
print(result.get_state_evolve(qc))
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_170/3633989060.py", line 1, in <module>
#     print(result.get_state_evolve(qc))
#   File "/opt/conda/lib/python3.8/site-packages/qiskit/result/result.py", line 128, in __getattr__
#     raise AttributeError(f"Attribute {name} is not defined") from ex
# AttributeError: Attribute get_state_evolve is not defined
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=AttributeError: Attribute get_state_evolve is not defined" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
print(result.get_counts(qc))
# Out:
# {'000': 0.5, '111': 0.5}

# %%
#Q33
bob=QuantumRegister(8,'b')
alice=ClassicalRegister(2,'a')
eve=QuantumRegister(4,'e')
qc=QuantumCircuit(bob,alice,eve)
qc.draw()
#print(qc.num_qubits)

# %%
print(qc.num_qubits)
# Out:
# 12

# %%
#Q34
qc=QuantumCircuit(1)
qc.z(0)
op=Operator(qc)
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_59/351605737.py", line 4, in <module>
#     op=Operator(qc)
# NameError: name 'Operator' is not defined
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=NameError: name 'Operator' is not defined" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>

# %%
qc.draw()

# %%
#Q37
import qiskit.quantum_info as qi
bell=QuantumCircuit(2)
bell.h(0)
bell.cx(0,1)

# %%
rho_bell=qi.DensityMatrix.from_instruction(bell)
rho_bell.draw()
# Out:
# 'DensityMatrix([[0.5+0.j, 0. +0.j, 0. +0.j, 0.5+0.j],\n               [0. +0.j, 0. +0.j, 0. +0.j, 0. +0.j],\n               [0. +0.j, 0. +0.j, 0. +0.j, 0. +0.j],\n               [0.5+0.j, 0. +0.j, 0. +0.j, 0.5+0.j]],\n              dims=(2, 2))'

# %%
#Q38
a=1/np.sqrt(2)
desired_state=[a,np.sqrt(1-a**2)]
qc=QuantumCircuit(1)
qc.initialize(desired_state,0)
back_sv=BasicAer.get_backend('statevector_simulator')
result=execute(qc,back_sv).result()
qc_sv=result.get_statevector(qc)
state_fidelity(desired_state,qc_sv)
# Out:
# 0.9999999999999998

# %%
qc.draw()

# %%
#Q39
a=Operator(XGate())
b=np.exp(1j/3)*a
average_gate_fidelity(a,b)
process_fidelity(a,b)
# Out:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_59/1641415608.py", line 2, in <module>
#     a=Operator(XGate())
# NameError: name 'Operator' is not defined
#
# Use %tb to get the full traceback.
# <style>
# .button {
#   border: none;
#   color: white;
#   padding: 4px 8px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 12px;
#   margin: 4px 2px;
#   transition-duration: 0.2s;
#   cursor: pointer;
# }
# .iqx-button {
#   background-color: #0f62fe;
#   color: white;
# }
# .iqx-button:hover {
#   background-color: #0043ce;
#   color: white;
# }
# </style>
# <a href="https://stackoverflow.com/search?q=NameError: name 'Operator' is not defined" target='_blank'><button class='button iqx-button'>Search for solution online</button></a>
